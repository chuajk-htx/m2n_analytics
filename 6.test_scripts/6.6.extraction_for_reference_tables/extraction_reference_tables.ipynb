# %% [markdown]
# # Extraction of Demographic Information from Image Database into a Text File

# %%
import pandas as pd
import gc
import os
from os import listdir
from os.path import isfile, join
import glob

# root is some folder or directory
root = r'C:\temp'
mylist = ['2']
for path, subdirs, files in os.walk(root):
     for name in files:
          mylist.append(os.path.join(path, name))

txt = open(r'C:\Users\B&P\Documents\analytics_platform\4.data_cleanup\extract_demographic_data.txt', 'w')
txt.write('dir' + ',' + 'file' + '\n')
for item in mylist:
     list = mylist.pop(0)
     dir, filename = os.path.basename(os.path.dirname(list)), os.path.basename(list)
     txt.write(dir + ',' + filename + '\n')

with open(r'C:\temp\output.txt', 'r') as f:
     read_data = f.read()
