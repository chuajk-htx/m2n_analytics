# %% [markdown]
# # Heatmap of quality and matching score

# %% [markdown]
# Things for consideration:
#
# 1. How to correlate quality score of enrolment and live against the matching score
#
# 2. Is there a relationship between quality score of the enrolment and live that affects the matching score? Is one more important/weighted than the other?
#
# 3. For the case of quality score, is there a relationship we can establish between enrolment and live to be "combined" into a single variable. Do we take the average or a weighted approach depending on their effects on quality.
#
# 4. Is there a trend between enrolment quality and live quality? Which one is usually higher than the other?
#
# 4a. Following this, does it mean that the other one is the "bottleneck"?
#
# The issue is now that we are dealing with 3-dimensions where all 3 may have some form of relationship with each other.
#
# 5. How do we deal with mated and non mated quality scores of the enrolled and live as compared to the matching scores.
#
# 6. One of the more useful variables we can do is taking the Quality of probe divide by the Quality of the enrolled, this will give us a normalised value to work with.
#
# One of the important bias to take note is that we do not have all the photo attempts being done, this is because the photo od the day given to us are those that have passed the threshold, and the failed attempts were not stored into the system.

# %% [markdown]
# ## 1. Quality Score normalization

# %%
# %reset

# First initialize the database connection

# From here we take each of the quality metric and divide them

# Store the above new quality metric into a dataframe where we can insert into the old dataframe

# Discard/delete all the unused dataframe/variables to free up memory as and when required.

# %%
# Using the new normalized quality metric, we are able to plot a graph of the matching scores against the normalized quality score

# In an ideal world, the normalized quality score is 1, this means that the quality of the live and enrolled photo are the same.

# One consideration to take note of is that we can plot 2 more graphs, normalized Q less than 1 and greater or equal to 1, against the matching score.

# This new graph can determine the matching score distribution between the quality
